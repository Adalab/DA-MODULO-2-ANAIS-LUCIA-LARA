# %%
import pandas as pd
import numpy as np
import sidetable

df= pd.read_csv('../Ficheros/attack_limpieza3.csv', index_col = 0)

# %% [markdown]
# Es el momento de ponernos a trabajar con los valores nulos 💪🏽. A lo largo de este ejercicio de pair programming vamos a intentar eliminar los valores nulos de nuestras columnas. En la lección hemos aprendido varios métodos, nosotras os planteamos los ejercicios pero sentiros libres de usar el método que más se adapte a vuestras necesidades. Manos a la obra!

# %% [markdown]
# 1. Lo primero que tenemos que evaluar es en que columnas tenemos nulos y que cantidad tenemos en cada una. ¿Hay alguna columna con una gran cantidad de nulos? En caso de que sea así deberemos eliminarla.

# %%
df.shape
# Out:
# (6284, 11)

# %%
df.stb.missing()
# Out:
#                missing  total    percent
# nuevas_edades     2860   6284  45.512412
# species_          2831   6284  45.050923
# age               2820   6284  44.875875
# fatal_             607   6284   9.659453
# mes                570   6284   9.070656
# sex2               564   6284   8.975175
# activity           542   6284   8.625080
# country             50   6284   0.795672
# case_number          1   6284   0.015913
# year                 0   6284   0.000000
# date                 0   6284   0.000000

# %%
nulos = pd.DataFrame((df.isnull().sum() * 100) / df.shape[0]).reset_index()
nulos.columns = ["columna", "porcentaje"]
nulos
# Out:
#           columna  porcentaje
# 0     case_number    0.015913
# 1            year    0.000000
# 2         country    0.795672
# 3        activity    8.625080
# 4             age   44.875875
# 5        species_   45.050923
# 6            date    0.000000
# 7             mes    9.070656
# 8          fatal_    9.659453
# 9            sex2    8.975175
# 10  nuevas_edades   45.512412

# %% [markdown]
# Es el momento de eliminar los nulos:

# %% [markdown]
# Reemplazad los valores nulos de la columna age por la media de la edad, redondeada a dos decimales.

# %%
media = round(df["nuevas_edades"].mean(),2)

# %%
df["nuevas_edades"].replace(np.nan, media, inplace = True)

# %%
df.stb.missing()
# Out:
#                missing  total    percent
# species_          2831   6284  45.050923
# age               2820   6284  44.875875
# fatal_             607   6284   9.659453
# mes                570   6284   9.070656
# sex2               564   6284   8.975175
# activity           542   6284   8.625080
# country             50   6284   0.795672
# case_number          1   6284   0.015913
# year                 0   6284   0.000000
# date                 0   6284   0.000000
# nuevas_edades        0   6284   0.000000

# %% [markdown]
# En relación a la columna de country al tratarse de una columna de tipo categórica, reemplazad los valores nulos por una nueva categória que se llame Unknown.

# %%
df["country"].replace(np.nan, "Unknown", inplace = True)

# %%
df.stb.missing()
# Out:
#                missing  total    percent
# species_          2831   6284  45.050923
# age               2820   6284  44.875875
# fatal_             607   6284   9.659453
# mes                570   6284   9.070656
# sex2               564   6284   8.975175
# activity           542   6284   8.625080
# case_number          1   6284   0.015913
# year                 0   6284   0.000000
# country              0   6284   0.000000
# date                 0   6284   0.000000
# nuevas_edades        0   6284   0.000000

# %% [markdown]
# Reemplazad los valores nulos de la columna fatal por Unknown.

# %%
df["fatal_"].replace(np.nan, "Unknown", inplace = True)

# %%
df.stb.missing()
# Out:
#                missing  total    percent
# species_          2831   6284  45.050923
# age               2820   6284  44.875875
# mes                570   6284   9.070656
# sex2               564   6284   8.975175
# activity           542   6284   8.625080
# case_number          1   6284   0.015913
# year                 0   6284   0.000000
# country              0   6284   0.000000
# date                 0   6284   0.000000
# fatal_               0   6284   0.000000
# nuevas_edades        0   6284   0.000000

# %% [markdown]
# Reemplazad los valores nulos de la columna type por el valor más frecuente (la moda).

# %%
# En su momento eliminamos la columna type, pero lo vamos a hacer con la columna activity.

# %%
moda_activity  = (df["activity"].mode())[0]
moda_activity
# Out:
# 'Surfing'

# %%
df[df["activity"]== "Surfing"]
# Out:
#      case_number  year       country activity    age     species_  \
# 11    1779.00.00  1977           usa  Surfing  young          NaN
# 69       ND-0122  1977           usa  Surfing    NaN          NaN
# 172   2018.06.09  2018           usa  Surfing     48          NaN
# 173   2018.06.08  2018     australia  Surfing    NaN  Unspecified
# 185   2018.05.12  2018  south africa  Surfing    NaN          NaN
# ...          ...   ...           ...      ...    ...          ...
# 5048  1936.01.05  1936     australia  Surfing     17  Unspecified
# 5075  1935.03.11  1935     australia  Surfing    NaN          NaN
# 5392  1922.01.04  1922     australia  Surfing     26          NaN
# 5436  1918.03.22  1918     australia  Surfing    NaN  Unspecified
# 6249  1828.00.00  1977           usa  Surfing    NaN          NaN
#
#               date  mes   fatal_ sex2  nuevas_edades
# 11            1779  NaN        y    M           27.3
# 69    Beforer 1994  NaN        n    M           27.3
# 172    09-Jun-2018  Jun        n    M           48.0
# 173    08-Jun-2018  Jun        n    M           27.3
# 185    12-May-2018  May        n    M           27.3
# ...            ...  ...      ...  ...            ...
# 5048   05-Jan-1936  Jan  Unknown    M           17.0
# 5075   11-Mar-1935  Mar        n    M           27.3
# 5392   04-Jan-1922  Jan        y    M           26.0
# 5436   22-Mar-1918  Mar        n    M           27.3
# 6249          1828  NaN        y    M           27.3
#
# [968 rows x 11 columns]

# %%
df["fatal_"].replace(np.nan, moda_activity, inplace = True)

# %%
df.stb.missing()
# Out:
#                missing  total    percent
# species_          2831   6284  45.050923
# age               2820   6284  44.875875
# mes                570   6284   9.070656
# sex2               564   6284   8.975175
# activity           542   6284   8.625080
# case_number          1   6284   0.015913
# year                 0   6284   0.000000
# country              0   6284   0.000000
# date                 0   6284   0.000000
# fatal_               0   6284   0.000000
# nuevas_edades        0   6284   0.000000

# %% [markdown]
# Reemplazad los valores nulos de la columna fecha por Unknown.

# %%
# En nuestro dataframe no hay nulos en la columna date, los vamos a reemplazar en la columna mes

# %%
df["mes"].replace(np.nan, "Unknown", inplace = True)

# %%
df.stb.missing()
# Out:
#                missing  total    percent
# species_          2831   6284  45.050923
# age               2820   6284  44.875875
# sex2               564   6284   8.975175
# activity           542   6284   8.625080
# case_number          1   6284   0.015913
# year                 0   6284   0.000000
# country              0   6284   0.000000
# date                 0   6284   0.000000
# mes                  0   6284   0.000000
# fatal_               0   6284   0.000000
# nuevas_edades        0   6284   0.000000

# %% [markdown]
# Guardad el csv para seguir trabajando con el en los siguientes ejercicios de pair.

# %%
df.to_csv("../Ficheros/attack_limpieza4.csv")
